# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# read the data
df = pd.read_csv('data/train5.csv')

# shape and data types of the data
print(df.shape)
print(df.dtypes)

# select numeric columns
df_raw_numeric = df.select_dtypes(include=[np.number])
numeric_cols = df_raw_numeric.columns.values
print(numeric_cols)

# select non numeric columns
df_raw_non_numeric = df.select_dtypes(exclude=[np.number])
non_numeric_cols = df_raw_non_numeric.columns.values
print(non_numeric_cols)

df.isnull().sum()
# Out:
# (1013451, 15)
# id                       int64
# cancel                   int64
# ni.age                 float64
# len.at.res             float64
# premium                float64
# ni.marital.status      float64
# n.adults               float64
# n.children             float64
# tenure                 float64
# claim.ind              float64
# ni.gender.lower         object
# sales.channel.lower     object
# coverage.type.lower     object
# dwelling.type.lower     object
# credit.lower            object
# dtype: object
# ['id' 'cancel' 'ni.age' 'len.at.res' 'premium' 'ni.marital.status'
#  'n.adults' 'n.children' 'tenure' 'claim.ind']
# ['ni.gender.lower' 'sales.channel.lower' 'coverage.type.lower'
#  'dwelling.type.lower' 'credit.lower']
# id                     0
# cancel                 0
# ni.age                 0
# len.at.res             0
# premium                0
# ni.marital.status      0
# n.adults               0
# n.children             0
# tenure                 0
# ...

# %%
# if it's a larger dataset and the visualization takes too long can do this.
# % of missing.
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# id - 0%
# cancel - 0%
# ni.age - 0%
# len.at.res - 0%
# premium - 0%
# ni.marital.status - 0%
# n.adults - 0%
# n.children - 0%
# tenure - 0%
# claim.ind - 0%
# ni.gender.lower - 0%
# sales.channel.lower - 0%
# coverage.type.lower - 0%
# dwelling.type.lower - 0%
# credit.lower - 0%

# %%
df['tenure'].hist(bins=100)
df['tenure'].describe()
# Out:
# count    1.013451e+06
# mean     1.164285e+01
# std      5.940781e+00
# min      0.000000e+00
# 25%      6.000000e+00
# 50%      1.300000e+01
# 75%      1.600000e+01
# max      3.400000e+01
# Name: tenure, dtype: float64

# %%
df['n.children'].hist(bins=100)
df['n.children'].describe()
# Out:
# count    1.013451e+06
# mean     1.728900e+00
# std      2.335964e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      2.000000e+00
# max      1.200000e+01
# Name: n.children, dtype: float64

# %%
df['n.adults'].hist(bins=100)
df['n.adults'].describe()
# Out:
# count    1.013451e+06
# mean     2.133752e+00
# std      1.253740e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      2.000000e+00
# 75%      3.000000e+00
# max      1.200000e+01
# Name: n.adults, dtype: float64

# %%
df['premium'].hist(bins=100)
df['premium'].describe()
print(df['premium'])
# Out:
# 0           950.507336
# 1           909.346046
# 2           897.084502
# 3           979.039007
# 4           932.379027
#               ...
# 1013446     926.857762
# 1013447     968.546580
# 1013448     838.446947
# 1013449    1026.261620
# 1013450     907.387213
# Name: premium, Length: 1013451, dtype: float64

# %%
df['len.at.res'].hist(bins=100)
df['len.at.res'].describe()
# Out:
# count    1.013451e+06
# mean     1.497560e+01
# std      3.872116e+00
# min      3.000000e+00
# 25%      1.200000e+01
# 50%      1.500000e+01
# 75%      1.800000e+01
# max      2.700000e+01
# Name: len.at.res, dtype: float64

# %%
df['ni.age'].hist(bins=100)
df['ni.age'].describe()
# Out:
# count    1.013451e+06
# mean     4.309728e+01
# std      1.114292e+01
# min      1.800000e+01
# 25%      3.500000e+01
# 50%      4.300000e+01
# 75%      5.100000e+01
# max      7.500000e+01
# Name: ni.age, dtype: float64

# %%
# bar chart -  distribution of a categorical variable
df['ni.gender.lower'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['ni.marital.status'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['sales.channel.lower'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['coverage.type.lower'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['dwelling.type.lower'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['credit.lower'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['ni.age'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['len.at.res'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['premium'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['n.adults'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['n.children'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['tenure'])
# Out:
# <AxesSubplot:>
